# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
# %matplotlib inline

response = requests.get('https://wopos.ru/wp-content/uploads/2018/08/17-1.jpeg')
img = Image.open(BytesIO(response.content))

plt.imshow(img)
